# %% [markdown]
# <a href="https://colab.research.google.com/github/marciacastro03/Estat-stica-Descritiva_MBA-Ci-ncia-de-Dados/blob/main/tab1_estatisticadescritiva.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_tabela = pd.read_csv('/content/Tabela1.csv', sep=";")
df_tabela
# Out:
#     id estado_civil      grau_instrucao  n_filhos salario_min  idade_anos  \
# 0    1     solteiro  ensino fundamental       NaN        4,00          26
# 1    2       casado  ensino fundamental       1.0        4,56          32
# 2    3       casado  ensino fundamental       2.0        5,25          36
# 3    4     solteiro        ensino médio       NaN        5,73          20
# 4    5     solteiro  ensino fundamental       NaN        6,26          40
# 5    6       casado  ensino fundamental       0.0        6,66          28
# 6    7     solteiro  ensino fundamental       NaN        6,86          41
# 7    8     solteiro  ensino fundamental       NaN        7,39          43
# 8    9       casado        ensino médio       1.0        7,44          34
# 9   10     solteiro        ensino médio       NaN        7,59          23
# 10  11       casado        ensino médio       2.0        8,12          33
# 11  12     solteiro  ensino fundamental       NaN        8,46          27
# 12  13     solteiro        ensino médio       NaN        8,74          37
# 13  14       casado  ensino fundamental       3.0        8,95          44
# 14  15       casado        ensino médio       0.0        9,13          30
# 15  16     solteiro        ensino médio       NaN        9,35          38
# 16  17       casado        ensino médio       1.0        9,77          31
# 17  18       casado  ensino fundamental       2.0        9,80          39
# 18  19     solteiro     ensino superior       NaN       10,35          25
# 19  20     solteiro        ensino médio       NaN       10,76          37
# 20  21       casado        ensino médio       1.0       11,06          30
# 21  22     solteiro        ensino médio       NaN       11,59          34
# 22  23     solteiro  ensino fundamental       NaN       12,00          41
# 23  24       casado     ensino superior       0.0       12,79          26
# 24  25       casado        ensino médio       2.0       13,23          32
# 25  26       casado        ensino médio       2.0       13,60          35
# 26  27     solteiro  ensino fundamental       NaN       13,85          46
# 27  28       casado        ensino médio       0.0       14,69          29
# 28  29       casado        ensino médio       5.0       14,71          40
# 29  30       casado        ensino médio       2.0       15,99          35
# 30  31     solteiro     ensino superior       NaN       16,22          31
# 31  32       casado        ensino médio       1.0       16,61          36
# 32  33       casado     ensino superior       3.0       17,26          43
# 33  34     solteiro     ensino superior       NaN       18,75          33
# 34  35       casado        ensino médio       2.0       19,40          48
# 35  36       casado     ensino superior       3.0       23,30          42
#
#     idade_meses regiao_procedencia
# 0             3           interior
# 1            10            capital
# 2             5            capital
# 3            10              outra
# 4             7              outra
# 5             0           interior
# 6             0           interior
# 7             4            capital
# 8            10            capital
# 9             6              outra
# 10            6           interior
# 11           11            capital
# 12            5              outra
# 13            2              outra
# 14            5           interior
# 15            8              outra
# 16            7            capital
# 17            7              outra
# 18            8           interior
# 19            4           interior
# 20            9              outra
# 21            2            capital
# 22            0              outra
# 23            1              outra
# 24            5           interior
# 25            0              outra
# 26            7              outra
# 27            8           interior
# 28            6           interior
# 29           10            capital
# 30            5              outra
# 31            4           interior
# 32            7            capital
# 33            7            capital
# 34           11            capital
# 35            2           interior

# %%
(df_tabela.estado_civil=="solteiro").sum()

## Frequências absolutas em casados e solteiros
freq_absoltua_solteiro = np.sum(df_tabela.estado_civil=="solteiro")
freq_absoluta_casado = np.sum(df_tabela.estado_civil=="casado")

# %%
## Frequência relativa de casados e solteiros
display(freq_absoltua_solteiro/(freq_absoltua_solteiro + freq_absoluta_casado))
display(freq_absoluta_casado/(freq_absoltua_solteiro + freq_absoluta_casado))
# Out:
# np.float64(0.4444444444444444)
# np.float64(0.5555555555555556)

# %%
df_tabela.grau_instrucao.unique()
# Out:
# array(['ensino fundamental', 'ensino médio', 'ensino superior'],
#       dtype=object)

# %%
freq_absoluta_ef = np.sum(df_tabela.grau_instrucao=='ensino fundamental')
freq_absoluta_em = np.sum(df_tabela.grau_instrucao=='ensino médio')
freq_absoluta_es = np.sum(df_tabela.grau_instrucao=='ensino superior')

print(
    freq_absoluta_ef, "\n",
    freq_absoluta_em, "\n",
    freq_absoluta_es
)
# Out:
# 12
#  18
#  6

# %%
print("Frequência relativa ou contagem normalizada:\n", df_tabela.grau_instrucao.value_counts(normalize=True))
print("\n----------------\n")
print("Frequência absoluta ou contagem não normalizada:\n", df_tabela.grau_instrucao.value_counts())
# Out:
# Frequência relativa ou contagem normalizada:
#  grau_instrucao
# ensino médio          0.500000
# ensino fundamental    0.333333
# ensino superior       0.166667
# Name: proportion, dtype: float64
#
# ----------------
#
# Frequência absoluta ou contagem não normalizada:
#  grau_instrucao
# ensino médio          18
# ensino fundamental    12
# ensino superior        6
# Name: count, dtype: int64
